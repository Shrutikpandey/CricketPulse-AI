# %%
# Step 1: Import Libraries
import pandas as pd
import os

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %%
# Step 2: Load the data
matches = pd.read_excel(r"C:\Users\Shruti Kumari Pandey\Desktop\My data analysis projects\CricketPulse-AI\data\matches.csv.xlsx")

print("Matches data loaded!")
print("Shape:", matches.shape)
# Out:
# Matches data loaded!
# Shape: (1095, 20)

# %%
# Step 3: Peek inside the data
matches.head()
# Out:
#        id   season        city       date match_type player_of_match  \
# 0  335982  2007/08   Bangalore 2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh 2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi 2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai 2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata 2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
# Step 4: See all column names
print(matches.columns.tolist())
# Out:
# ['id', 'season', 'city', 'date', 'match_type', 'player_of_match', 'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result', 'result_margin', 'target_runs', 'target_overs', 'super_over', 'method', 'umpire1', 'umpire2']

# %%
# Step 8: See all column names
print(matches.columns.tolist())
# Out:
# ['id', 'season', 'city', 'date', 'match_type', 'player_of_match', 'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result', 'result_margin', 'target_runs', 'target_overs', 'super_over', 'method', 'umpire1', 'umpire2']

# %%
# Step 9: Check missing values
print(matches.isnull().sum())
# Out:
# id                    0
# season                0
# city                  0
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                0
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
# Step 10: Check seasons in our data
print("Seasons covered:", sorted(matches['season'].unique()))
print("Total matches:", len(matches))
print("Total teams:", matches['team1'].nunique())
print("Total venues:", matches['venue'].nunique())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Step 10: Check seasons in our data
# ----> 2 print("Seasons covered:", sorted(matches['season'].unique()))
#       3 print("Total matches:", len(matches))
#       4 print("Total teams:", matches['team1'].nunique())
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
# Step 10: Check seasons in our data
print("Seasons covered:", matches['season'].unique())
print("Total matches:", len(matches))
print("Total teams:", matches['team1'].nunique())
print("Total venues:", matches['venue'].nunique())
# Out:
# Seasons covered: ['2007/08' 2009 '2009/10' 2011 2012 2013 2014 2015 2016 2017 2018 2019
#  '2020/21' 2021 2022 2023 2024]
# Total matches: 1095
# Total teams: 19
# Total venues: 58

# %%
# Step 11: Fix season column
matches['season'] = matches['season'].astype(str)
matches['season'] = matches['season'].str.replace('2007/08', '2008')
matches['season'] = matches['season'].str.replace('2009/10', '2010')
matches['season'] = matches['season'].str.replace('2020/21', '2021')

print("Seasons fixed:")
print(sorted(matches['season'].unique()))
# Out:
# Seasons fixed:
# ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2021', '2022', '2023', '2024']

# %%
# Step 12: Load deliveries data
deliveries = pd.read_excel(r"C:\Users\Shruti Kumari Pandey\Desktop\My Data Analysis Projects\CricketPulse-AI\data\deliveries.xlsx")

print("Deliveries data loaded!")
print("Shape:", deliveries.shape)
print("Columns:", deliveries.columns.tolist())
# Out:
# Deliveries data loaded!
# Shape: (260920, 18)
# Columns: ['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket', 'player_dismissed', 'dismissal_kind', 'fielder', 'Cities']

# %%
# Step 13: Check missing values in deliveries
print(deliveries.isnull().sum())
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# Cities                   0
# dtype: int64

# %%
# Step 14: Save cleaned data
matches.to_csv(r"C:\Users\Shruti Kumari Pandey\Desktop\My Data Analysis Projects\CricketPulse-AI\data\matches_cleaned.csv", index=False)

deliveries.to_csv(r"C:\Users\Shruti Kumari Pandey\Desktop\My Data Analysis Projects\CricketPulse-AI\data\deliveries_cleaned.csv", index=False)

print("✅ Cleaned data saved successfully!")
# Out:
# ✅ Cleaned data saved successfully!
